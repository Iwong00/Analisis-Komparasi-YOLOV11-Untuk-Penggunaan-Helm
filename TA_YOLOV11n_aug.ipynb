# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.2 MB/s eta 0:00:00
# ...

# %%
# !cat /content/drive/MyDrive/TA/data/helmet/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 2
# names: ['helmet', 'no_helmet']
#
# roboflow:
#   workspace: buah-jpm59
#   project: helmet-pdryu
#   version: 2
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/buah-jpm59/helmet-pdryu/dataset/2

# %%
# !yolo detect train \
model=yolo11n.pt \
data=/content/drive/MyDrive/TA/data/helmet/data.yaml \
epochs=100 \
imgsz=512 \
batch=16 \
project=/content/drive/MyDrive/TA/result/result_v11n_aug \
name=train \
hsv_h=0.01 \
hsv_s=0.5 \
hsv_v=0.3 \
degrees=3 \
translate=0.05 \
scale=0.4 \
fliplr=0.5 \
mosaic=0.5 \
mixup=0.05
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo detect val \
model=/content/drive/MyDrive/TA/result/result_v11n_aug/train/weights/best.pt \
data=/content/drive/MyDrive/TA/data/helmet/data.yaml \
project=/content/drive/MyDrive/TA/result/result_v11n_aug \
name=validation
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.3 ms, read: 22.4±2.1 MB/s, size: 43.1 KB)
# val: Scanning /content/drive/MyDrive/TA/data/helmet/valid/labels.cache... 400 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 400/400 47.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 5.6it/s 4.4s
#                    all        400        614      0.894      0.887      0.939        0.6
#                 helmet        272        308      0.913      0.935      0.967      0.674
#              no_helmet        220        306      0.874       0.84      0.911      0.527
# Speed: 1.3ms preprocess, 2.9ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/drive/MyDrive/TA/result/result_v11n_aug/validation
# ...

# %%
# !yolo detect val \
model=/content/drive/MyDrive/TA/result/result_v11n_aug/train/weights/best.pt \
data=/content/drive/MyDrive/TA/data/helmet/data.yaml \
split=test \
project=/content/drive/MyDrive/TA/result/result_v11n_aug \
name=test
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 0.1±0.0 MB/s, size: 47.4 KB)
# val: Scanning /content/drive/MyDrive/TA/data/helmet/test/labels.cache... 200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 28.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s
#                    all        200        317      0.917      0.856      0.943       0.59
#                 helmet        135        155      0.902      0.916      0.961      0.648
#              no_helmet        107        162      0.933      0.796      0.925      0.533
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to /content/drive/MyDrive/TA/result/result_v11n_aug/test
# ...

# %%
# !yolo detect predict \
model=/content/drive/MyDrive/TA/result/result_v11n_aug/train/weights/best.pt \
source=/content/drive/MyDrive/TA/data/helmet/test/images \
conf=0.25 \
save=True \
project=/content/drive/MyDrive/TA/result/result_v11n_aug \
name=prediction
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-121-_png.rf.b2a13faa10ae883592cf26e744f7c09b.jpg: 512x512 (no detections), 10.3ms
# image 2/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-133-_png.rf.4dc158dd5c6cd6a7a5c756f2be784996.jpg: 512x512 1 helmet, 9.0ms
# image 3/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-134-_png.rf.bd99fd650c3d52d022b067905953ad9a.jpg: 512x512 2 helmets, 12.7ms
# image 4/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-142-_png.rf.d639b9f2efcf77994c8d2c8847863094.jpg: 512x512 1 helmet, 8.8ms
# image 5/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-158-_png.rf.80a9bab2d64c519cb329cd3b396e183e.jpg: 512x512 1 helmet, 8.7ms
# ...
