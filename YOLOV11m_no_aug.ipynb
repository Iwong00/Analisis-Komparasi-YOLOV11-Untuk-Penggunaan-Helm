# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 36.2 MB/s eta 0:00:00
# ...

# %%
# !cat /content/drive/MyDrive/TA/data/helmet/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 2
# names: ['helmet', 'no_helmet']
#
# roboflow:
#   workspace: buah-jpm59
#   project: helmet-pdryu
#   version: 2
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/buah-jpm59/helmet-pdryu/dataset/2

# %%
# !yolo detect train \
model=yolo11m.pt \
data=/content/drive/MyDrive/TA/data/helmet/data.yaml \
epochs=100 \
imgsz=512 \
batch=16 \
project=/content/drive/MyDrive/TA/result/result_v11m_no_aug \
name=train
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.28 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo detect val \
model=/content/drive/MyDrive/TA/result/result_v11m_no_aug/train/weights/best.pt \
data=/content/drive/MyDrive/TA/data/helmet/data.yaml \
project=/content/drive/MyDrive/TA/result/result_v11m_no_aug \
name=validation
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 126 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.6±0.3 ms, read: 0.1±0.0 MB/s, size: 44.2 KB)
# val: Scanning /content/drive/MyDrive/TA/data/helmet/valid/labels.cache... 400 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 400/400 83.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 25/25 2.3it/s 11.0s
#                    all        400        614      0.957       0.89      0.962      0.605
# ...

# %%
# !yolo detect val \
model=/content/drive/MyDrive/TA/result/result_v11m_no_aug/train/weights/best.pt \
data=/content/drive/MyDrive/TA/data/helmet/data.yaml \
split=test \
project=/content/drive/MyDrive/TA/result/result_v11m_no_aug \
name=test
# Out:
# Ultralytics 8.4.28 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 126 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.9±0.4 ms, read: 0.1±0.0 MB/s, size: 40.1 KB)
# val: Scanning /content/drive/MyDrive/TA/data/helmet/test/labels.cache... 200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 28.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.4it/s 5.5s
#                    all        200        317      0.944      0.906      0.956      0.605
#                 helmet        135        155      0.935      0.934      0.969      0.651
#              no_helmet        107        162      0.953      0.879      0.943      0.559
# Speed: 2.2ms preprocess, 19.6ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to /content/drive/MyDrive/TA/result/result_v11m_no_aug/test
# ...

# %%
# !yolo detect predict \
model=/content/drive/MyDrive/TA/result/result_v11m_no_aug/train/weights/best.pt \
source=/content/drive/MyDrive/TA/data/helmet/test/images \
conf=0.25 \
save=True \
project=/content/drive/MyDrive/TA/result/result_v11m_no_aug \
name=prediction
# Out:
# Ultralytics 8.4.28 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 126 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-121-_png.rf.b2a13faa10ae883592cf26e744f7c09b.jpg: 512x512 1 helmet, 25.6ms
# image 2/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-133-_png.rf.4dc158dd5c6cd6a7a5c756f2be784996.jpg: 512x512 2 helmets, 25.5ms
# image 3/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-134-_png.rf.bd99fd650c3d52d022b067905953ad9a.jpg: 512x512 2 helmets, 25.5ms
# image 4/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-142-_png.rf.d639b9f2efcf77994c8d2c8847863094.jpg: 512x512 1 helmet, 25.5ms
# image 5/200 /content/drive/MyDrive/TA/data/helmet/test/images/helmet-158-_png.rf.80a9bab2d64c519cb329cd3b396e183e.jpg: 512x512 1 helmet, 25.6ms
# ...

# %%
# !yolo detect predict \
model=/content/drive/MyDrive/TA/result/result_v11m_no_aug/train/weights/best.pt \
source=/content/drive/MyDrive/TA/data/helmet/valid/images \
conf=0.25 \
save=True \
project=/content/drive/MyDrive/TA/result/result_v11m_no_aug \
name=prediction_valid
# Out:
# Ultralytics 8.4.28 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 126 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/400 /content/drive/MyDrive/TA/data/helmet/valid/images/helmet-1-_png.rf.d53bd9f48546a79332563a615f770ce7.jpg: 512x512 2 helmets, 1 no_helmet, 25.6ms
# image 2/400 /content/drive/MyDrive/TA/data/helmet/valid/images/helmet-100-_png.rf.d90734f026ea5300ea5a626c59a20690.jpg: 512x512 1 helmet, 25.6ms
# image 3/400 /content/drive/MyDrive/TA/data/helmet/valid/images/helmet-106-_png.rf.1d0a57230d79b8c8a2b86b59e45adfc9.jpg: 512x512 1 helmet, 25.6ms
# image 4/400 /content/drive/MyDrive/TA/data/helmet/valid/images/helmet-107-_png.rf.8e6e0806ed94a4ee5f3adf5d318a29f4.jpg: 512x512 1 helmet, 25.6ms
# image 5/400 /content/drive/MyDrive/TA/data/helmet/valid/images/helmet-11-_png.rf.b5e40ea8e15516d0dc56b6fee6af0429.jpg: 512x512 1 helmet, 39.0ms
# ...
